# %% [markdown]
# # Million songs Recomendation Engine
# - Using python library `Recomenders`
#
# The dataset contains 2 files:
# - The triplet_file contains user_id, song_id and listen time.
# - The metadata_file contains song_id, title, release, year and artist_name.
#
#
# Million Songs Dataset is a mixture of song from various website with the rating that users gave after listening to the song.
#
# ### Import Modules

# %%
import numpy as np 
import pandas as pd 
import Recommenders as Recommenders

# %% [markdown]
# ### Load dataset

# %%
song_df = pd.read_csv('triplets_file.csv')
song_df.head(5)
# Out:
#                                     user_id             song_id  listen_count
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1

# %%
song_df2 = pd.read_csv('song_data.csv')
song_df2.head(5)
# Out:
#               song_id              title  \
# 0  SOQMMHC12AB0180CB8       Silent Night
# 1  SOVFVAK12A8C1350D9        Tanssi vaan
# 2  SOGTUKN12AB017F4F1  No One Could Ever
# 3  SOBNYVR12A8C13558C      Si Vos Querés
# 4  SOHSBXH12A8C13B0DF   Tangle Of Aspens
#
#                                 release       artist_name  year
# 0                 Monster Ballads X-Mas  Faster Pussy cat  2003
# 1                           Karkuteillä  Karkkiautomaatti  1995
# 2                                Butter    Hudson Mohawke  2006
# 3                               De Culo       Yerba Brava  2003
# 4  Rene Ablaze Presents Winter Sessions        Der Mystic     0

# %%
# combine both dataset 

song_df = pd.merge(song_df, song_df2.drop_duplicates(['song_id']), on = 'song_id', how = 'left')

song_df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title                        release    artist_name  year
# 0         The Cove             Thicker Than Water   Jack Johnson     0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999

# %% [markdown]
# ### Data Preprocessing

# %%
# creating a new feature song , by combining artist name and title
song_df['song'] = song_df['artist_name'] + '-' +song_df['title']
song_df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title                        release    artist_name  year  \
# 0         The Cove             Thicker Than Water   Jack Johnson     0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999
#
#                             song
# 0          Jack Johnson-The Cove
# 1  Paco De Lucia-Entre Dos Aguas
# 2            Kanye West-Stronger
# 3    Jack Johnson-Constellations
# 4      Foo Fighters-Learn To Fly

# %%
# trimming upto to 10k results for faster prediction 
song_df = song_df.head(10000)

# gropu songs by the number of poeple tuning in  
song_grouped = song_df.groupby(['song']).aggregate({"listen_count":"count"}).reset_index()

song_grouped.head(5)
# Out:
#                                                 song  listen_count
# 0            + / - {Plus/Minus}-The Queen of Nothing             2
# 1                                 10 Years-Beautiful             1
# 2  112-Only You-Bad Boy Remix (Featuring The Noto...             1
# 3          12 Stones-The Way I Feel (Not Our Master)             3
# 4                                 16Volt-Machine Kit             1

# %%
gropuped_sum = song_grouped['listen_count'].sum()
song_grouped['percentge'] = (song_grouped['listen_count']/gropuped_sum)*100
song_grouped.sort_values(['listen_count','song'], ascending=False)
# Out:
#                                                    song  listen_count  \
# 1994                             Harmonia-Sehr kosmisch            45
# 1402                       Dwight Yoakam-You're The One            32
# 515                                          Björk-Undo            32
# 3429                                OneRepublic-Secrets            28
# 1694  Florence + The Machine-Dog Days Are Over (Radi...            28
# ...                                                 ...           ...
# 6                                  1990s-Pollockshields             1
# 5                                     1990s-Cult Status             1
# 4                                    16Volt-Machine Kit             1
# 2     112-Only You-Bad Boy Remix (Featuring The Noto...             1
# 1                                    10 Years-Beautiful             1
#
#       percentge
# 1994       0.45
# 1402       0.32
# 515        0.32
# 3429       0.28
# 1694       0.28
# ...         ...
# 6          0.01
# 5          0.01
# 4          0.01
# 2          0.01
# 1          0.01
#
# [5151 rows x 3 columns]

# %% [markdown]
# ### Popularity Recommendation

# %%
# picking a random user 
song_df[song_df.index == 12]['song']
# Out:
# 12    The B-52's-Love Shack
# Name: song, dtype: object

# %%
# creating a popularity based recommendation for that user 

reco = Recommenders.popularity_recommender_py()

reco.create(song_df, 'user_id','song')

reco.recommend(song_df['user_id'][12])
# Out:
#                                        user_id  \
# 1994  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 515   b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1402  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1694  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3429  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 988   b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 2603  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 2598  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 874   b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 374   b80344d063b5ccb3212f76538f3d9e43d87dca9e
#
#                                                    song  score  Rank
# 1994                             Harmonia-Sehr kosmisch     45   1.0
# 515                                          Björk-Undo     32   2.0
# 1402                       Dwight Yoakam-You're The One     32   3.0
# 1694  Florence + The Machine-Dog Days Are Over (Radi...     28   4.0
# 3429                                OneRepublic-Secrets     28   5.0
# 988                              Coldplay-The Scientist     27   6.0
# 2603                         Kings Of Leon-Use Somebody     27   7.0
# 2598                              Kings Of Leon-Revelry     26   8.0
# 874                        Charttraxx Karaoke-Fireflies     24   9.0
# 374   Barry Tuckwell/Academy of St Martin-in-the-Fie...     23  10.0

# %% [markdown]
# ### Item similarity Recommendation

# %%
reco = Recommenders.item_similarity_recommender_py()
reco.create(song_df, 'user_id','song')

user_items = reco.get_user_items(song_df['user_id'][12])

# the song history of the user 
for user in user_items[:10]:
    print(user)
# Out:
# Jack Johnson-The Cove
# Paco De Lucia-Entre Dos Aguas
# Kanye West-Stronger
# Jack Johnson-Constellations
# Foo Fighters-Learn To Fly
# Héroes del Silencio-Apuesta Por El Rock 'N' Roll
# Lady GaGa-Paper Gangsta
# Foo Fighters-Stacked Actors
# Harmonia-Sehr kosmisch
# Thievery Corporation feat. Emiliana Torrini-Heaven's gonna burn your eyes

# %%
# recommending the user some songs 

reco.recommend(song_df['user_id'][12])
# Out:
# No. of unique songs for the user: 45
# no. of unique songs in the training set: 5151
# Non zero values in cooccurence_matrix :6844
#                                     user_id  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 5  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 6  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 7  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 8  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 9  b80344d063b5ccb3212f76538f3d9e43d87dca9e
#
#                                       song     score  rank
# 0                 Fleet Foxes-Oliver James  0.043076     1
# 1                 Fleet Foxes-Quiet Houses  0.043076     2
# 2               Fleet Foxes-Your Protector  0.043076     3
# 3  Fleet Foxes-Tiger Mountain Peasant Song  0.043076     4
# 4                 Fleet Foxes-Sun It Rises  0.043076     5
# 5                        Pearl Jam-The End  0.037531     6
# 6                Dave Grusin-St. Elsewhere  0.037531     7
# 7                       Céline Dion-Misled  0.037531     8
# 8                    Incubus-Oil And Water  0.037531     9
# 9                  Fleet Foxes-Meadowlarks  0.037531    10

# %%
# give realative songs to the user base don the words

reco.get_similar_items(['Fleet Foxes-Oliver James','Fleet Foxes-Quiet Houses'])
# Out:
# no. of unique songs in the training set: 5151
# Non zero values in cooccurence_matrix :92
#   user_id                                               song     score  rank
# 0                                 Fleet Foxes-Your Protector  1.000000     1
# 1                    Fleet Foxes-Tiger Mountain Peasant Song  1.000000     2
# 2                                   Fleet Foxes-Sun It Rises  1.000000     3
# 3                            Fleet Foxes-He Doesn't Know Why  0.666667     4
# 4             Velvet Underground & Nico-There She Goes Again  0.500000     5
# 5                Pixies-Wave of Mutilation (UK Surf Version)  0.500000     6
# 6                             Fleet Foxes-Drops In The River  0.500000     7
# 7          The Velvet Underground-Oh! Sweet Nuthin' (LP V...  0.500000     8
# 8                                             Pixies-Debaser  0.500000     9
# 9                               Pixies-Monkey Gone To Heaven  0.500000    10
